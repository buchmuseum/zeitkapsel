# %%
import os
import pandas as pd
from datetime import datetime


def generate_pica(row):
    pica = f"\n0600 yy\n"
    if (row.obj1 == 'Schreibzeug') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d\n"
    if (row.obj1 == 'Schreibzeug') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;v-cont\n"

    if (row.obj1 == 'Plakat') and int(row.umfang) < 2:
        pica += f"0500 Pa\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-ganz\n"
    if (row.obj1 == 'Plakat') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-cont\n"

    if (row.obj1 == 'Postkarte') and int(row.umfang) < 2:
        pica += f"0500 Pa\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-ganz\n"
    if (row.obj1 == 'Postkarte') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-cont\n"

    if (row.obj1 == 'Katalog') and int(row.umfang) < 2:
        pica += f"0500 Aa\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-ganz\n2105 04,P01\n"
    if (row.obj1 == 'Katalog') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-kodex;v-cont\n"

    if (row.obj1 == 'Optischer Speicher') and int(row.umfang) < 2:
        pica += f"0500 Sa\n0501 Computerdaten$bcod\n0502 Computermedien$bc\n0503 Computerdisk$bcd\n1130 DA-crom\n1132 a1-digital\n"
    if (row.obj1 == 'Optischer Speicher') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Computerdaten$bcod\n0502 Computermedien$bc\n0503 Computerdisk$bcd\n1130 Da-crom\n1132 a1-digital;v-cont\n"

    if (row.obj1 == 'Akzidenz') and int(row.umfang) < 2:
        pica += f"0500 Aa\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-ganz\n2105 04,P01\n"
    if (row.obj1 == 'Akzidenz') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-cont\n"

    if (row.obj1 == 'Werbegeschenk') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;\n"
    if (row.obj1 == 'Werbegeschenk') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;v-cont\n"

    if (row.obj1 == 'Spielzeug') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d\n"
    if (row.obj1 == 'Spielzeug') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;v-cont\n"

    if (row.obj1 == 'Audiovisuelles Material') and int(row.umfang) < 2:
        pica += f"0500 Sa\n0501 gesprochenes Wort$bspw\n0502 audio$bs\n0503 Audiodisk$bsd\n1130 To-cdda\n1132 a1-digital;f2-3d\n"
    if (row.obj1 == 'Audiovisuelles Material') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 gesprochenes Wort$bspw\n0502 audio$bs\n0503 Audiodisk$bsd\n1130 To-cdda\n1132 a1-digital;f2-3d;v-cont\n"

    if (row.obj1 == 'Textilien') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-gewebe\n1132 a1-analog;f2-3d;\n"
    if (row.obj1 == 'Textilien') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-gewebe\n1132 a1-analog;f2-3d;v-cont\n"

    if (row.obj1 == 'Notizbuch') and int(row.umfang) < 2:
        pica += f"0500 Aa\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f2-blatt;v-ganz\n2105 04,P01\n"
    if (row.obj1 == 'Notizbuch') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f2-blatt;v-cont\n"

    if (row.obj1 == 'Kalender') and int(row.umfang) < 2:
        pica += f"0500 Aa\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f2-blatt;v-ganz\n2105 04,P01\n"
    if (row.obj1 == 'Kalender') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f2-blatt;v-cont\n"

    if (row.obj1 == 'Gebrauchsgegenstand') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;\n"
    if (row.obj1 == 'Gebrauchsgegenstand') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;v-cont\n"

    if (row.obj1 == 'Lesezeichen') and int(row.umfang) < 2:
        pica += f"0500 Pa\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-ganz\n"
    if (row.obj1 == 'Lesezeichen') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-cont\n"

    if (row.obj1 == 'Packmittel') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;\n"
    if (row.obj1 == 'Packmittel') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;v-cont\n"


    if pd.notna(row.jahrz):
        pica += f"1100 {row.jahrn}$n{row.jahrz}\n"
    elif pd.notna(row.jahrn):
        pica += f"1100 {row.jahrn}\n"
    

    if pd.isna(row.jahrn):
        pica += f"1100 2023$n[nicht nach 2023]\n"

    if pd.notna(row.sprache):
        pica +=f"1500 /1{row.sprache}\n"


    if pd.notna(row.personidn):
        pica += f"3000 {row.personidn}$BGeistiger Schöpfer$4cre\n"

    if pd.notna(row.verlagsidn):
        pica += f"3100 {row.verlagsidn}$BHerausgebendes Organ$4isb\n"

    pica += f"4000 {row.titel} "

    if pd.notna(row.verlagsn):
        pica += f"/ {row.verlagsn}"

    if pd.notna(row.person):
        pica += f" / {row.person}"

    pica += f"\n"
        
    if pd.notna(row.gat3):
        pica += f"4019 {row.gat3}$Bobja\n"

    if pd.notna(row.gat2):
        pica += f"4019 {row.gat2}$Bobja\n"
       
    if pd.notna(row.gat1):
        pica += f"4019 {row.gat1}$Bobja\n"
    if pd.isna(row.gat1) and pd.isna(row.gat2) and pd.isna(row.gat3):
        pica += f"4019 {row.obj1}$Bobja\n"   

    if pd.notna(row.text):
            pica += f"4019 {row.text}$Btext\n"

    if int(row.umfang) < 2:
        if pd.notna(row.gat3):
            pica +=f"4060 {row.umfang} {row.gat3}\n"
        if pd.notna(row.gat2):
            pica +=f"4060 {row.umfang} {row.gat2}\n"
        if pd.notna(row.gat1):
            pica +=f"4060 {row.umfang} {row.gat1}\n"
        if pd.isna(row.gat1) and pd.isna(row.gat2) and pd.isna(row.gat3):
            pica += f"4060 {row.umfang} {row.obj1}\n"

    if int(row.umfang) > 1:
        if pd.notna(row.gat3):
            if (row.gat3 == 'Aufkleber'):
                pica += f"4060 {row.umfang} Aufkleber" 
            if (row.gat3 == 'Aufsteller'):
                pica += f"4060 {row.umfang} Aufsteller" 
            if (row.gat3 == 'Button'):
                pica += f"4060 {row.umfang} Buttons" 
            if (row.gat3 == 'Flaschenöffner'):
                pica += f"4060 {row.umfang} Flaschenöffner" 
            if (row.gat3 == 'Kunststoffflasche'):
                pica += f"4060 {row.umfang} Kunststoffflaschen" 
            if (row.gat3 == 'Luftballon'):
                pica += f"4060 {row.umfang} Luftballons" 
            if (row.gat3 == 'Magnet'):
                pica += f"4060 {row.umfang} Magnete" 
            if (row.gat3 == 'Schlüsselband'):
                pica += f"4060 {row.umfang} Schlüsselbänder" 
            if (row.gat3 == 'Schlüsselanhänger'):
                pica += f"4060 {row.umfang} Schlüsselanhänger"
        if pd.notna(row.gat2):  
            if (row.gat2 == 'Bleistift'):
                pica += f"4060 {row.umfang} Bleistife"  
            if (row.gat2 == 'Filzstift'):
                pica += f"4060 {row.umfang} Filzstifte" 
            if (row.gat2 == 'Kugelschreiber'):
                pica += f"4060 {row.umfang} Kugelschreiber" 
            if (row.gat2 == 'Lineal'):
                pica += f"4060 {row.umfang} Lineale" 
            if (row.gat2 == 'Straßenkreide'):
                pica += f"4060 {row.umfang} Straßenkreide" 
            if (row.gat2 == 'Radiergummi'):
                pica += f"4060 {row.umfang} Radiergummis" 
            if (row.gat2 == 'Stempelkissen'):
                pica += f"4060 {row.umfang} Stempelkissen" 
            if (row.gat2 == 'Wachsstift'):
                pica += f"4060 {row.umfang} Wachsstifte" 
         


    if pd.notna(row.breite) and pd.isna(row.höhe):
        pica +=f"4062 {row.breite} x {row.länge} cm$b{row.breite}$h{row.länge}$4mesa\n"
    if pd.notna(row.breite) and pd.notna(row.höhe):
        pica +=f"4062 {row.breite} x {row.länge} x {row.höhe} cm$b{row.breite}$h{row.länge}$l{row.höhe}$4mesa\n"

    pica += f"4105 {row.qdidn}\n"
    pica += f"4105 !129410330X!\n"
    pica += f"4700 |BSM|\n"

    pica += f"5590 Objektgattung\n"

    if (row.obj1 == 'Spielzeug'):
        pica += f"5590 !040562484!\n"
    if (row.obj1 == 'Audiovisuelles Material'):
        pica += f"5590 !955174120!\n"
    if (row.obj1 == 'Optischer Speicher'):
        pica += f"5590 !041726790!\n"
    if (row.obj1 == 'Gebrauchsgegenstand'):
        pica += f"5590 !041213203!\n"
    if (row.obj1 == 'Kalender'):
        pica += f"5590 !040292908!\n"
    if (row.obj1 == 'Katalog'):
        pica += f"5590 !041877888!\n" 
    if (row.obj1 == 'Akzidenz'):
        pica += f"5590 !041942175!\n"
    if (row.obj1 == 'Lesezeichen'):
        pica += f"5590 !943194164!\n"
    if (row.obj1 == 'Notizbuch'):
        pica += f"5590 !04225695X!\n"
    if (row.obj1 == 'Plakat'):
        pica += f"5590 !04046198X!\n"
    if (row.obj1 == 'Postkarte'):
        pica += f"5590 !040469026!\n"
    if (row.obj1 == 'Textilien'):
        pica += f"5590 !04059615X!\n"
    if (row.obj1 == 'Werbegeschenk'):
        pica += f"5590 !041378113!\n"
    if pd.notna(row.gat1):
        if (row.gat1 == 'Bausatz'):
            pica += f"5590 !976540894!\n"
        if (row.gat1 == 'Beutel'):
            pica += f"5590 !96534715X!\n"
        if (row.gat1 == 'Broschüre'):
            pica += f"5590 !041467043!\n"

        if (row.gat1 == 'CD-ROM'):
            pica += f"5590 !041393074!\n"
        if (row.gat1 == 'Handzettel'):
            pica += f"5590 !042930286!\n"
        if (row.gat1 == 'Hörbuch'):
            pica += f"5590 !940089343!\n"
        if (row.gat1 == 'Kartenspiel'):
            pica += f"5590 !040297985!\n"
        if (row.gat1 == 'Sammelobjekt'):
            pica += f"5590 !94153765X!\n" 
        if (row.gat1 == 'Schmuck'):
            pica += f"5590 !040529452!\n" 
        if (row.gat1 == 'Spielzeugfigur'):
            pica += f"5590 !991211960!\n"
        if (row.gat1 == 'Stofftier'):
            pica += f"5590 !040576914!\n"   
        if (row.gat1 == 'Tasse'):
            pica += f"5590 !041844882!\n"   
        if (row.gat1 == 'Tonträger'):
            pica += f"5590 !041343646!\n"   
        if (row.gat1 == 'T-Shirt'):
            pica += f"5590 !04302761X!\n"   
        if (row.gat1 == 'Tuch'):
            pica += f"5590 !940730944!\n"  
        if (row.gat1 == 'USB'):
            pica += f"5590 !97051350X!\n"  
        if (row.gat1 == 'Katalog'):
            pica += f"5590 !041877888!\n"  
        if (row.gat1 == 'Visitenkarte'):
            pica += f"5590 !041884094!\n"  
        if (row.gat1 == 'Wundverband'):
            pica += f"5590 !94794477X!\n"  
        if (row.gat1 == 'Tüte'):
            pica += f"5590 !953363872!\n"  
    if pd.notna(row.gat2):  

        if (row.gat2 == 'Bleistift'):
            pica += f"5590 !041210352!\n"  
        if (row.gat2 == 'Filzstift'):
            pica += f"5590 !041249739!\n" 
        if (row.gat2 == 'Kugelschreiber'):
            pica += f"5590 !955518245!\n" 
        if (row.gat2 == 'Lineal'):
            pica += f"5590 !941947084!\n" 
        if (row.gat2 == 'Straßenkreide'):
            pica += f"5590 !041799828!\n" 
        if (row.gat2 == 'Radiergummi'):
            pica += f"5590 !958214182!\n" 
        if (row.gat2 == 'Stempelkissen'):
            pica += f"5590 !966466829!\n" 
        if (row.gat2 == 'Wachsstift'):
            pica += f"5590 Wachsstift\n" 

    if pd.notna(row.gat3): 
        if (row.gat3 == 'Aufkleber'):
            pica += f"5590 !041209427!\n" 
        if (row.gat3 == 'Aufsteller'):
            pica += f"5590 !983759839!\n" 
        if (row.gat3 == 'Button'):
            pica += f"5590 !041376676!\n" 
        if (row.gat3 == 'Flaschenöffner'):
            pica += f"5590 !975720694!\n" 
        if (row.gat3 == 'Kunststoffflasche'):
            pica += f"5590 !969296991!\n" 
        if (row.gat3 == 'Luftballon'):
            pica += f"5590 !042703328!\n" 
        if (row.gat3 == 'Magnet'):
            pica += f"5590 !041315766!\n" 
        if (row.gat3 == 'Schlüsselband'):
            pica += f"5590 Schlüsselband\n" 
        if (row.gat3 == 'Schlüsselanhänger'):
            pica += f"5590 !974747858!\n" 


    if pd.notna(row.material):
        material = row.material.split( )
        pica += f"5591 [Material]\n5591 {material[1]}\n"


    if pd.notna(row.bemerk):
        pica +=f"4201 {row.bemerk}\n"



    pica +=f"""7001 x
4800 !009033645!
6710 !!
"""
    if pd.notna(row.verlagsn):
        pica +=f"7100 ZK - {row.verlagsn} - \n7109 !!DBSM/S!! ; ZK - {row.verlagsn} - \n"
    else:
        pica +=f"7100 ZK - {row.person} - \n7109 !!DBSM/S!! ; ZK - {row.person} - \n"

       
    pica +="\t\n"

    return pica


ordnerpfad = "../tab/"
neue_daten = []

for dateiname in os.listdir(ordnerpfad):
    if dateiname.endswith('.xlsx') or dateiname.endswith('.xls'):
        dateipfad = os.path.join(ordnerpfad, dateiname)
        daten = pd.read_excel(dateipfad, names=['obj1','gat1','gat2','gat3','titel','jahrn','jahrz','sprache','text','land','umfang','breite','länge','höhe','material','bemerk','verlagsn','verlagsidn','verlagsk','qdidn','person','personidn'], dtype='string')
        daten[(daten.obj1 == 'Sonstiges')].to_excel(f"../offen/sonstiges.xlsx", index=False)
        daten = daten[daten['obj1'] != 'Sonstiges']
        daten = daten.apply(lambda x: x.str.strip())
        neue_daten.extend(daten.apply(generate_pica, axis=1))

df_neue_daten = pd.DataFrame(neue_daten, columns=['PICA'])
df_neue_daten.to_csv(f'../dat/gesamte_daten.dat', index=False)
