# %%
import pandas as pd

# %%
# öffne alle Dateien eines Ordners nach eine andere und löse die Befehle aus
df = pd.read_excel('H2, F529, LeipzigerGrafikbörse.xlsx', names=['obj1','gat1','gat2','gat3','titel','jahrn','jahrz','sprache','text','land','umfang','breite','länge','höhe','material','bemerk','verlagsn','verlagsidn','verlagsk','qdidn','person','personidn'], dtype='string')
df = df.apply(lambda x: x.str.strip())
df.head()
# Out:
#         obj1        gat1  gat2  gat3  \
# 0   Akzidenz   Broschüre  <NA>  <NA>
# 1  Postkarte        <NA>  <NA>  <NA>
# 2   Akzidenz  Handzettel  <NA>  <NA>
#
#                                        titel jahrn jahrz sprache  text  land  \
# 0                    Sammlung von Broschüren  <NA>  <NA>     ger  <NA>  <NA>
# 1  Postkarte "www.leipziger-grafikboerse.de"  <NA>  <NA>     ger  <NA>  <NA>
# 2          Handzettel "Werden Sie Mitglied!"  <NA>  <NA>     ger  <NA>  <NA>
#
#    ... länge  höhe            material bemerk               verlagsn  \
# 0  ...    21  <NA>  Papier !040445224!   <NA>  Leipziger Grafikbörse
# 1  ...    11  <NA>  Papier !040445224!   <NA>  Leipziger Grafikbörse
# 2  ...    21  <NA>  Papier !040445224!   <NA>  Leipziger Grafikbörse
#
#      verlagsidn verlagsk         qdidn person personidn
# 0  !1052674690!     <NA>  !128694404X!   <NA>      <NA>
# 1  !1052674690!     <NA>  !128694404X!   <NA>      <NA>
# ...

# %%
def pica_schreiben(row):
        
    pica = f"0600 yy\n"

    if (row.obj1 == 'Schreibzeug') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;e2-uv\n"
    if (row.obj1 == 'Schreibzeug') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;e2-uv\n"

    if (row.obj1 == 'Plakat') and int(row.umfang) < 2:
        pica += f"0500 Pa\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-ganz\n"
    if (row.obj1 == 'Plakat') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-ganz\n"

    if (row.obj1 == 'Postkarte') and int(row.umfang) < 2:
        pica += f"0500 Pa\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-ganz\n"
    if (row.obj1 == 'Postkarte') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 unbewegtes Bild$bsti\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Blatt$bnb\n1130 TB-Papier\n1132 a1-analog;f1-bild;v-ganz\n"

    if (row.obj1 == 'Verlagskataloge') and int(row.umfang) < 2:
        pica += f"0500 Aa\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-ganz\n"
    if (row.obj1 == 'Verlagskataloge') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-ganz\n"

    if (row.obj1 == 'USB') and int(row.umfang) < 2:
        pica += f"0500 Sa\n0501 Computerdaten$bcod\n0502 Computermedien$bc\n0503 Computerdisk$bcd\n1130 TB-sonst\n1132 ?\n"
    if (row.obj1 == 'USB') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Computerdaten$bcod\n0502 Computermedien$bc\n0503 Computerdisk$bcd\n1130 TB-sonst\n1132 ?\n"

    if (row.obj1 == 'Akzidenz') and int(row.umfang) < 2:
        pica += f"0500 Aa\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-ganz\n"
    if (row.obj1 == 'Akzidenz') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 Text$btxt\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Band$bnc\n1130 TB-Papier\n1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-ganz\n"

    if (row.obj1 == 'Werbegeschenk') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;e2-uv\n"
    if (row.obj1 == 'Werbegeschenk') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;e2-uv\n"

    if (row.obj1 == 'Spielzeug') and int(row.umfang) < 2:
        pica += f"0500 Xa\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;e2-uv\n"
    if (row.obj1 == 'Spielzeug') and int(row.umfang) > 1:
        pica += f"0500 Qd\n0501 dreidimensionale Form$btdf\n0502 ohne Hilfsmittel zu benutzen$bn\n0503 Gegenstand$bnr\n1130 TB-sonst\n1132 a1-analog;f2-3d;e2-uv\n"

    pica +=f"0600 yy\n"

    if pd.notna(row.jahrz):
        pica += f"1100 {row.jahrn}$n{row.jahrz}\n"
    elif pd.notna(row.jahrn):
        pica += f"1100 {row.jahrn}\n"
    

    if pd.isna(row.jahrn):
        pica += f"1100 2023$n[nicht nach 2023]\n"

    if pd.notna(row.sprache):
        sprache = row.sprache.split( )
        pica +=f"1500 /1{sprache[0]}"

        # pica +=f"/1{sprache[1]}"
        # pica +=f"/1{sprache[2]}"

    pica +=f"\n" 

    if pd.notna(row.personidn):
        pica += f"3000 {row.personidn}$BGeistiger Schöpfer$4cre\n"

    if pd.notna(row.verlagsidn):
        pica += f"3100 {row.verlagsidn}$BHerausgebendes Organ$4isb\n"

    pica += f"4000 {row.titel} "

    if pd.notna(row.verlagsn):
        pica += f"/ {row.verlagsn}"

    if pd.notna(row.person):
        pica += f" / {row.person}"

    pica += f"\n"
        
    if pd.notna(row.gat3):
        pica += f"4019 {row.gat3}$Bobja\n"

    if pd.notna(row.gat2):
        pica += f"4019 {row.gat2}$Bobja\n"
       
    if pd.notna(row.gat1):
        pica += f"4019 {row.gat1}$Bobja\n"
    if pd.isna(row.gat1) and pd.isna(row.gat2) and pd.isna(row.gat3):
        pica += f"4019 {row.obj1}$Bobja\n"   

    if pd.notna(row.text):
            pica += f"4019 {row.text}$Btext\n"

    if int(row.umfang) < 2:
        if pd.notna(row.gat3):
            pica +=f"4060 {row.umfang} {row.gat3}\n"
        if pd.notna(row.gat2):
            pica +=f"4060 {row.umfang} {row.gat2}\n"
        if pd.notna(row.gat1):
            pica +=f"4060 {row.umfang} {row.gat1}\n"
        if pd.isna(row.gat1) and pd.isna(row.gat2) and pd.isna(row.gat3):
            pica += f"4060 {row.umfang} {row.obj1}\n"

    if int(row.umfang) > 1:
        if pd.notna(row.gat3):
            if (row.gat3 == 'Aufkleber'):
                pica += f"4060 {row.umfang} Aufkleber" 
            if (row.gat3 == 'Aufsteller'):
                pica += f"4060 {row.umfang} Aufsteller" 
            if (row.gat3 == 'Button'):
                pica += f"4060 {row.umfang} Buttons" 
            if (row.gat3 == 'Flaschenöffner'):
                pica += f"4060 {row.umfang} Flaschenöffner" 
            if (row.gat3 == 'Kunststoffflasche'):
                pica += f"4060 {row.umfang} Kunststoffflaschen" 
            if (row.gat3 == 'Luftballon'):
                pica += f"4060 {row.umfang} Luftballons" 
            if (row.gat3 == 'Magnet'):
                pica += f"4060 {row.umfang} Magnete" 
            if (row.gat3 == 'Schlüsselband'):
                pica += f"4060 {row.umfang} Schlüsselbänder" 
            if (row.gat3 == 'Schlüsselanhänger'):
                pica += f"4060 {row.umfang} Schlüsselanhänger"
        if pd.notna(row.gat2):  
            if (row.gat2 == 'Bleistift'):
                pica += f"4060 {row.umfang} Bleistife"  
            if (row.gat2 == 'Filzstift'):
                pica += f"4060 {row.umfang} Filzstifte" 
            if (row.gat2 == 'Kugelschreiber'):
                pica += f"4060 {row.umfang} Kugelschreiber" 
            if (row.gat2 == 'Lineal'):
                pica += f"4060 {row.umfang} Lineale" 
            if (row.gat2 == 'Straßenkreide'):
                pica += f"4060 {row.umfang} Straßenkreide" 
            if (row.gat2 == 'Radiergummi'):
                pica += f"4060 {row.umfang} Radiergummis" 
            if (row.gat2 == 'Stempelkissen'):
                pica += f"4060 {row.umfang} Stempelkissen" 
            if (row.gat2 == 'Wachsstift'):
                pica += f"4060 {row.umfang} Wachsstifte" 
         


    if pd.notna(row.breite) and pd.isna(row.höhe):
        pica +=f"4062 {row.breite} x {row.länge} cm$b{row.breite}h{row.länge}$4mesa\n"
    if pd.notna(row.breite) and pd.notna(row.höhe):
        pica +=f"4062 {row.breite} x {row.länge} x {row.höhe} cm$b{row.breite}$h{row.länge}$l{row.höhe}$4mesa\n"

    pica += f"4105 {row.qdidn}\n"

    pica += f"5590 Objektgattung\n"

    if (row.obj1 == 'Spielzeug'):
        pica += f"5590 !040562484!\n"
    if (row.obj1 == 'Audiovisuelles Material'):
        pica += f"5590 !955174120!\n"
    if (row.obj1 == 'Optischer Speicher'):
        pica += f"5590 !041726790!\n"
    if (row.obj1 == 'Gebrauchsgegenstand'):
        pica += f"5590 !041213203!\n"
    if (row.obj1 == 'Kalender'):
        pica += f"5590 !040292908!\n"
    if (row.obj1 == 'Akzidenz'):
        pica += f"5590 !041942175!\n"
    if (row.obj1 == 'Lesezeichen'):
        pica += f"5590 !943194164!\n"
    if (row.obj1 == 'Notizbuch'):
        pica += f"5590 !04225695X!\n"
    if (row.obj1 == 'Plakat'):
        pica += f"5590 !04046198X!\n"
    if (row.obj1 == 'Postkarte'):
        pica += f"5590 !040469026!\n"
    if (row.obj1 == 'Textilien'):
        pica += f"5590 !04059615X!\n"
    if (row.obj1 == 'Werbeartikel'):
        pica += f"5590 !041378113!\n"
    if pd.notna(row.gat1):
        if (row.gat1 == 'Bausatz'):
            pica += f"5590 !976540894!"
        if (row.gat1 == 'Beutel'):
            pica += f"5590 !96534715X!"
        if (row.gat1 == 'Broschüre'):
            pica += f"5590 !041467043!"

        if (row.gat1 == 'CD-ROM'):
            pica += f"5590 !041393074!"
        if (row.gat1 == 'Handzettel'):
            pica += f"5590 !042930286!"
        if (row.gat1 == 'Hörbuch'):
            pica += f"5590 !940089343!"
        if (row.gat1 == 'Kartenspiel'):
            pica += f"5590 !040297985!"
        if (row.gat1 == 'Sammelobjekt'):
            pica += f"5590 !94153765X!" 
        if (row.gat1 == 'Schmuck'):
            pica += f"5590 !040529452!" 
        if (row.gat1 == 'Spielzeugfigur'):
            pica += f"5590 !991211960!"
        if (row.gat1 == 'Stofftier'):
            pica += f"5590 !040576914!"   
        if (row.gat1 == 'Tasse'):
            pica += f"5590 !041844882!"   
        if (row.gat1 == 'Tonträger'):
            pica += f"5590 !041343646!"   
        if (row.gat1 == 'T-Shirt'):
            pica += f"5590 !04302761X!"   
        if (row.gat1 == 'Tuch'):
            pica += f"5590 !940730944!"  
        if (row.gat1 == 'USB'):
            pica += f"5590 !97051350X!"  
        if (row.gat1 == 'Katalog'):
            pica += f"5590 !041877888!"  
        if (row.gat1 == 'Visitenkarte'):
            pica += f"5590 !041884094!"  
        if (row.gat1 == 'Wundverband'):
            pica += f"5590 !94794477X!"  
        if (row.gat1 == 'Tüte'):
            pica += f"5590 !953363872!"  
    if pd.notna(row.gat2):  

        if (row.gat2 == 'Bleistift'):
            pica += f"5590 !asw!"  
        if (row.gat2 == 'Filzstift'):
            pica += f"5590 !!" 
        if (row.gat2 == 'Kugelschreiber'):
            pica += f"5590 !!" 
        if (row.gat2 == 'Lineal'):
            pica += f"5590 !!" 
        if (row.gat2 == 'Straßenkreide'):
            pica += f"5590 !!" 
        if (row.gat2 == 'Radiergummi'):
            pica += f"5590 !!" 
        if (row.gat2 == 'Stempelkissen'):
            pica += f"5590 !!" 
        if (row.gat2 == 'Wachsstift'):
            pica += f"5590 !!" 

    if pd.notna(row.gat3): 
        if (row.gat3 == 'Aufkleber'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Aufsteller'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Button'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Flaschenöffner'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Kunststoffflasche'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Luftballon'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Magnet'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Schlüsselband'):
            pica += f"5590 !!" 
        if (row.gat3 == 'Schlüsselanhänger'):
            pica += f"5590 !!" 

    pica += f"\n"

    if pd.notna(row.material):
        material = row.material.split( )
        pica += f"5591 [Material]\n5591 {material[1]}\n"


    if pd.notna(row.bemerk):
        pica +=f"4201 {row.bemerk}\n"



    pica +=f"""7001 x
4800 !009033645!
6710 !!
"""
    if pd.notna(row.verlagsn):
        pica +=f"7100 ZK - {row.verlagsn} - \n7109 !!DBSM/S!! ; ZK - {row.verlagsn} - \n"
    else:
        pica +=f"7100 ZK - {row.person} - \n7109 !!DBSM/S!! ; ZK - {row.person} - \n"

    
        pica +="\t\n"

    return pica

# %%
for index, row in df.iterrows():
    print(pica_schreiben(row))
# Out:
# 0600 yy
# 0500 Qd
# 0501 Text$btxt
# 0502 ohne Hilfsmittel zu benutzen$bn
# 0503 Band$bnc
# 1130 TB-Papier
# 1132 a1-analog;a2-druck;f1-text;f2-blatt;f2-kodex;v-ganz
# 0600 yy
# 1100 2023$n[nicht nach 2023]
# 1500 /1ger
# 3100 !1052674690!$BHerausgebendes Organ$4isb
# 4000 Sammlung von Broschüren / Leipziger Grafikbörse
# 4019 Broschüre$Bobja
# 4062 10 x 21 cm$b10h21$4mesa
# 4105 !128694404X!
# 5590 Objektgattung
# 5590 !041942175!
# 5590 !041467043!
# 5591 [Material]
# 5591 !040445224!
# 7001 x
# 4800 !009033645!
# 6710 !!
# 7100 ZK - Leipziger Grafikbörse -
# 7109 !!DBSM/S!! ; ZK - Leipziger Grafikbörse -
#
# 0600 yy
# 0500 Pa
# 0501 unbewegtes Bild$bsti
# 0502 ohne Hilfsmittel zu benutzen$bn
# 0503 Blatt$bnb
# 1130 TB-Papier
# 1132 a1-analog;f1-bild;v-ganz
# 0600 yy
# 1100 2023$n[nicht nach 2023]
# 1500 /1ger
# 3100 !1052674690!$BHerausgebendes Organ$4isb
# 4000 Postkarte "www.leipziger-grafikboerse.de" / Leipziger Grafikbörse
# 4019 Postkarte$Bobja
# 4060 1 Postkarte
# ...
